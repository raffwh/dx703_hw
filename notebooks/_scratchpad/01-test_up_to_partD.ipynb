# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter


from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight

random_seed = 42

# %%
data = load_breast_cancer(as_frame=True)

df = data.frame

# %%
X = df.drop(columns=['target']).to_numpy()
y = df['target'].to_numpy()

# %%
y_total = len(y)
y_one = sum(y)

# %% [markdown]
# -----
#
# # Part B

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed, stratify=y)

# %%
partb_scaler = StandardScaler()

x_train = partb_scaler.fit_transform(x_train)
x_test = partb_scaler.transform(x_test)

# %%
y_total = len(y)
y_one = sum(y)

y_train_one = sum(y_train)

print(f"y_total: {y_total}")
print(f"y_one: {y_one}")
print(f"y_train_one: {y_train_one}")
print(f"y_train percentage: {y_train_one/len(y_train)}")
# Out:
# y_total: 569
# y_one: 357
# y_train_one: 285
# y_train percentage: 0.6263736263736264

# %%
sum(y_train) / len(y_train)
# Out:
# np.float64(0.6263736263736264)
